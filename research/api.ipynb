# %% [markdown]
# # Load config

# %%
import yaml
with open("../config.yaml") as f:
    config = yaml.safe_load(f)

# %% [markdown]
# # Alpaca py sample
#
# Data only available from December 2015 onwards

# %%
import datetime

from alpaca.data.historical import StockHistoricalDataClient
from alpaca.data.requests import StockBarsRequest
from alpaca.data.timeframe import TimeFrame

    

client = StockHistoricalDataClient(config['alpaca']['key'], config['alpaca']['secret'])

assets = ["SPY", "IEF", "TLT", "GLD", "VNQ"]

request_params = StockBarsRequest(
                        symbol_or_symbols=assets,
                        timeframe=TimeFrame.Day,
                        start=datetime.datetime(2012, 7, 1)
                 )

bars = client.get_stock_bars(request_params).df
bars
# Out:
#                                       open     high      low   close  \
# symbol timestamp
# GLD    2015-12-01 05:00:00+00:00  102.3000  102.430  101.810  102.28
#        2015-12-02 05:00:00+00:00  101.3500  101.350  100.530  100.69
#        2015-12-03 05:00:00+00:00  101.2300  101.970  100.845  101.76
#        2015-12-04 05:00:00+00:00  102.7400  104.210  102.650  104.02
#        2015-12-07 05:00:00+00:00  103.3200  103.370  102.500  102.67
# ...                                    ...      ...      ...     ...
# VNQ    2023-02-27 05:00:00+00:00   86.5400   87.150   85.470   85.84
#        2023-02-28 05:00:00+00:00   85.8020   86.840   85.620   85.72
#        2023-03-01 05:00:00+00:00   85.1200   85.370   83.960   84.64
#        2023-03-02 05:00:00+00:00   84.0400   85.760   83.920   85.63
#        2023-03-03 05:00:00+00:00   86.3099   87.125   86.060   86.93
#
#                                       volume  trade_count        vwap
# symbol timestamp
# GLD    2015-12-01 05:00:00+00:00   4645916.0      19450.0  102.161847
#        2015-12-02 05:00:00+00:00  10223492.0      42784.0  100.947089
#        2015-12-03 05:00:00+00:00   6499935.0      30659.0  101.426721
#        2015-12-04 05:00:00+00:00  10670249.0      48021.0  103.717041
#        2015-12-07 05:00:00+00:00   4393461.0      23083.0  102.879428
# ...                                      ...          ...         ...
# VNQ    2023-02-27 05:00:00+00:00   5170988.0      58570.0   86.112348
#        2023-02-28 05:00:00+00:00   7262105.0      65269.0   86.218755
#        2023-03-01 05:00:00+00:00   7042052.0      76889.0   84.524911
#        2023-03-02 05:00:00+00:00   5208876.0      56857.0   84.902620
#        2023-03-03 05:00:00+00:00   4542142.0      52913.0   86.748589
#
# [9130 rows x 7 columns]

# %% [markdown]
# # cTrader Open API sample

# %%
def transformTrendbar(trendbar):
    openTime = datetime.datetime.fromtimestamp(trendbar.utcTimestampInMinutes * 60, datetime.timezone.utc)
    openPrice = (trendbar.low + trendbar.deltaOpen) / 100000.0
    highPrice = (trendbar.low + trendbar.deltaHigh) / 100000.0
    lowPrice = trendbar.low / 100000.0
    closePrice = (trendbar.low + trendbar.deltaClose) / 100000.0
    return [openTime, openPrice, highPrice, lowPrice, closePrice, trendbar.volume]

symbolName = "EURUSD"

# %%
from ctrader_open_api import Client, Protobuf, TcpProtocol, Auth, EndPoints
from ctrader_open_api.messages.OpenApiCommonMessages_pb2 import *
from ctrader_open_api.messages.OpenApiMessages_pb2 import *
from ctrader_open_api.messages.OpenApiModelMessages_pb2 import *
from twisted.internet import reactor
import json
import datetime
import calendar

host = EndPoints.PROTOBUF_LIVE_HOST if config["ctrader"]["hostType"].lower() == "live" else EndPoints.PROTOBUF_DEMO_HOST
client = Client(host, EndPoints.PROTOBUF_PORT, TcpProtocol)

dailyBars = []

def onError(failure): # Call back for errors
    print("Message Error: ", failure)

def disconnected(client, reason): # Callback for client disconnection
    print("\nDisconnected: ", reason)

def onMessageReceived(client, message): # Callback for receiving all messages
    print("Message received: \n", Protobuf.extract(message))

def connected(client): # Callback for client connection
    print("\nConnected")
    # Now we send a ProtoOAApplicationAuthReq
    request = ProtoOAApplicationAuthReq()
    request.clientId = config["ctrader"]["id"]
    request.clientSecret = config["ctrader"]["secret"]
    # Client send method returns a Twisted deferred
    deferred = client.send(request)
    # You can use the returned Twisted deferred to attach callbacks
    # for getting message response or error backs for getting error if something went wrong
    deferred.addCallbacks(applicationAuthResponseCallback, onError)
    deferred.addErrback(onError)

def applicationAuthResponseCallback(result):
    print("\nApplication authenticated")
    request = ProtoOAAccountAuthReq()
    request.ctidTraderAccountId = config["ctrader"]["accountId"]
    request.accessToken = config["ctrader"]["accessToken"]
    deferred = client.send(request)
    deferred.addCallbacks(accountAuthResponseCallback, onError)

def accountAuthResponseCallback(result):
    print("\nAccount authenticated")
    request = ProtoOASymbolsListReq()
    request.ctidTraderAccountId = config["ctrader"]["accountId"]
    request.includeArchivedSymbols = False
    deferred = client.send(request)
    deferred.addCallbacks(symbolsResponseCallback, onError)

def symbolsResponseCallback(result):
    print("\nSymbols received")
    symbols = Protobuf.extract(result)
    symbolsFilterResult = list(filter(lambda symbol: symbol.symbolName == symbolName, symbols.symbol))
    if len(symbolsFilterResult) == 0:
        raise Exception(f"There is symbol that matches to your defined symbol name: {symbolName}")
    elif len(symbolsFilterResult) > 1:
        raise Exception(f"More than one symbol matched with your defined symbol name: {symbolName}, match result: {symbolsFilterResult}")
    symbol = symbolsFilterResult[0]
    request = ProtoOAGetTrendbarsReq()
    request.symbolId = symbol.symbolId
    request.ctidTraderAccountId = config["ctrader"]["accountId"]
    request.period = ProtoOATrendbarPeriod.D1
    # We set the from/to time stamps to 50 weeks, you can load more data by sending multiple requests
    # Please check the ProtoOAGetTrendbarsReq documentation for more detail
    request.fromTimestamp = int(calendar.timegm((datetime.datetime.utcnow() - datetime.timedelta(weeks=50)).utctimetuple())) * 1000
    request.toTimestamp = int(calendar.timegm(datetime.datetime.utcnow().utctimetuple())) * 1000
    deferred = client.send(request)
    deferred.addCallbacks(trendbarsResponseCallback, onError)

def trendbarsResponseCallback(result):
    print("\nTrendbars received")
    trendbars = Protobuf.extract(result)
    barsData = list(map(transformTrendbar, trendbars.trendbar))
    global dailyBars
    dailyBars.clear()
    dailyBars.extend(barsData)
    print("\ndailyBars length:", len(dailyBars))
    print("\Stopping reactor...")
    reactor.stop()


# Setting optional client callbacks
client.setConnectedCallback(connected)
client.setDisconnectedCallback(disconnected)
client.setMessageReceivedCallback(onMessageReceived)

# %%
# Starting the client service
client.startService()
# Run Twisted reactor
reactor.run()
# Out:
# Connected
# Message received:
#
#
# Application authenticated
# Message received:
#  ctidTraderAccountId: 24136091
#
#
# Account authenticated
# Message received:
#  ctidTraderAccountId: 24136091
# symbol {
#   symbolId: 10020
#   symbolName: "XNGUSD"
#   enabled: true
#   baseAssetId: 45
#   quoteAssetId: 16
#   symbolCategoryId: 7
#   description: "Natural Gas"
# }
# symbol {
#   symbolId: 44
#   symbolName: "XAGEUR"
#   enabled: true
#   baseAssetId: 17
#   quoteAssetId: 5
#   symbolCategoryId: 2
#   description: "Silver vs Euro"
# }
# symbol {
#   symbolId: 42
#   symbolName: "XAGUSD"
#   enabled: true
#   baseAssetId: 17
#   quoteAssetId: 16
#   symbolCategoryId: 2
#   description: "Silver vs US Dollar"
# }
# symbol {
#   symbolId: 43
#   symbolName: "XAUEUR"
#   enabled: true
#   baseAssetId: 18
#   quoteAssetId: 5
#   symbolCategoryId: 2
#   description: "Gold vs Euro"
# }
# symbol {
#   symbolId: 41
#   symbolName: "XAUUSD"
#   enabled: true
#   baseAssetId: 18
#   quoteAssetId: 16
#   symbolCategoryId: 2
#   description: "Gold vs US Dollar"
# }
# symbol {
#   symbolId: 10016
#   symbolName: "XPDUSD"
#   enabled: true
#   baseAssetId: 41
#   quoteAssetId: 16
#   symbolCategoryId: 2
#   description: "Palladium"
# }
# symbol {
#   symbolId: 10017
#   symbolName: "XPTUSD"
#   enabled: true
#   baseAssetId: 42
#   quoteAssetId: 16
#   symbolCategoryId: 2
#   description: "Platinum"
# }
# symbol {
#   symbolId: 10032
#   symbolName: "XAUAUD"
#   enabled: false
#   baseAssetId: 18
#   quoteAssetId: 1
#   symbolCategoryId: 2
#   description: "Gold vs Australian Dollar"
# }
# symbol {
#   symbolId: 1
#   symbolName: "EURUSD"
#   enabled: true
#   baseAssetId: 5
#   quoteAssetId: 16
#   symbolCategoryId: 1
#   description: "Euro vs US Dollar"
# }
# symbol {
#   symbolId: 5
#   symbolName: "AUDUSD"
#   enabled: true
#   baseAssetId: 1
#   quoteAssetId: 16
#   symbolCategoryId: 1
#   description: "Australian vs US Dollar"
# }
# symbol {
#   symbolId: 2
#   symbolName: "GBPUSD"
#   enabled: true
#   baseAssetId: 6
#   quoteAssetId: 16
#   symbolCategoryId: 1
#   description: "British Pound vs US Dollar"
# }
# symbol {
#   symbolId: 8
#   symbolName: "USDCAD"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 2
#   symbolCategoryId: 1
#   description: "US Dollar vs Canadian"
# }
# symbol {
#   symbolId: 6
#   symbolName: "USDCHF"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 3
#   symbolCategoryId: 1
#   description: "US Dollar vs Swiss Franc"
# }
# symbol {
#   symbolId: 4
#   symbolName: "USDJPY"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 9
#   symbolCategoryId: 1
#   description: "US Dollar vs Japanese Yen"
# }
# symbol {
#   symbolId: 18
#   symbolName: "AUDCAD"
#   enabled: true
#   baseAssetId: 1
#   quoteAssetId: 2
#   symbolCategoryId: 1
#   description: "Australian Dollar vs Canadian Dollar"
# }
# symbol {
#   symbolId: 23
#   symbolName: "AUDCHF"
#   enabled: true
#   baseAssetId: 1
#   quoteAssetId: 3
#   symbolCategoryId: 1
#   description: "Australian Dollar vs Swiss Franc"
# }
# symbol {
#   symbolId: 38
#   symbolName: "AUDDKK"
#   enabled: false
#   baseAssetId: 1
#   quoteAssetId: 4
#   symbolCategoryId: 1
#   description: "Australian Dollar vs Danish Krone"
# }
# symbol {
#   symbolId: 11
#   symbolName: "AUDJPY"
#   enabled: true
#   baseAssetId: 1
#   quoteAssetId: 9
#   symbolCategoryId: 1
#   description: "Australian Dollar vs Japanese Yen"
# }
# symbol {
#   symbolId: 20
#   symbolName: "AUDNZD"
#   enabled: true
#   baseAssetId: 1
#   quoteAssetId: 12
#   symbolCategoryId: 1
#   description: "Australian vs New Zealand Dollar"
# }
# symbol {
#   symbolId: 15
#   symbolName: "CADJPY"
#   enabled: true
#   baseAssetId: 2
#   quoteAssetId: 9
#   symbolCategoryId: 1
#   description: "Canadian Dollar vs Japanese Yen"
# }
# symbol {
#   symbolId: 27
#   symbolName: "CADCHF"
#   enabled: true
#   baseAssetId: 2
#   quoteAssetId: 3
#   symbolCategoryId: 1
#   description: "Canadian Dollar vs Swiss Franc"
# }
# symbol {
#   symbolId: 1001
#   symbolName: "AUDSGD"
#   enabled: true
#   baseAssetId: 1
#   quoteAssetId: 15
#   symbolCategoryId: 1
#   description: "Australian Dollar vs Singapore Dollar"
# }
# symbol {
#   symbolId: 13
#   symbolName: "CHFJPY"
#   enabled: true
#   baseAssetId: 3
#   quoteAssetId: 9
#   symbolCategoryId: 1
#   description: "Swiss Franc vs Japanese Yen"
# }
# symbol {
#   symbolId: 1002
#   symbolName: "CHFSGD"
#   enabled: true
#   baseAssetId: 3
#   quoteAssetId: 15
#   symbolCategoryId: 1
#   description: "Swiss Franc vs Singapore Dollar"
# }
# symbol {
#   symbolId: 14
#   symbolName: "EURAUD"
#   enabled: true
#   baseAssetId: 5
#   quoteAssetId: 1
#   symbolCategoryId: 1
#   description: "Euro vs Australian Dollar"
# }
# symbol {
#   symbolId: 17
#   symbolName: "EURCAD"
#   enabled: true
#   baseAssetId: 5
#   quoteAssetId: 2
#   symbolCategoryId: 1
#   description: "Euro vs Canadian Dollar"
# }
# symbol {
#   symbolId: 10
#   symbolName: "EURCHF"
#   enabled: true
#   baseAssetId: 5
#   quoteAssetId: 3
#   symbolCategoryId: 1
#   description: "Euro vs Swiss Franc"
# }
# symbol {
#   symbolId: 1024
#   symbolName: "EURCZK"
#   enabled: false
#   baseAssetId: 5
#   quoteAssetId: 21
#   symbolCategoryId: 1
#   description: "Euro vs Czech Koruna"
# }
# symbol {
#   symbolId: 1003
#   symbolName: "EURDKK"
#   enabled: true
#   baseAssetId: 5
#   quoteAssetId: 4
#   symbolCategoryId: 1
#   description: "Euro vs Danish Krone"
# }
# symbol {
#   symbolId: 1004
#   symbolName: "EURHKD"
#   enabled: true
#   baseAssetId: 5
#   quoteAssetId: 7
#   symbolCategoryId: 1
#   description: "Euro vs Hong Kong Dollar"
# }
# symbol {
#   symbolId: 34
#   symbolName: "EURHUF"
#   enabled: false
#   baseAssetId: 5
#   quoteAssetId: 8
#   symbolCategoryId: 1
#   description: "Euro vs Hungarian Forint"
# }
# symbol {
#   symbolId: 9
#   symbolName: "EURGBP"
#   enabled: true
#   baseAssetId: 5
#   quoteAssetId: 6
#   symbolCategoryId: 1
#   description: "Euro vs British Pound"
# }
# symbol {
#   symbolId: 3
#   symbolName: "EURJPY"
#   enabled: true
#   baseAssetId: 5
#   quoteAssetId: 9
#   symbolCategoryId: 1
#   description: "Euro vs Japanese Yen"
# }
# symbol {
#   symbolId: 1022
#   symbolName: "EURMXN"
#   enabled: false
#   baseAssetId: 5
#   quoteAssetId: 10
#   symbolCategoryId: 1
#   description: "Euro vs Mexican Peso"
# }
# symbol {
#   symbolId: 33
#   symbolName: "EURNOK"
#   enabled: true
#   baseAssetId: 5
#   quoteAssetId: 11
#   symbolCategoryId: 1
#   description: "Euro vs Norwegian Krone"
# }
# symbol {
#   symbolId: 26
#   symbolName: "EURNZD"
#   enabled: true
#   baseAssetId: 5
#   quoteAssetId: 12
#   symbolCategoryId: 1
#   description: "Euro vs New Zealand Dollar"
# }
# symbol {
#   symbolId: 1005
#   symbolName: "EURPLN"
#   enabled: true
#   baseAssetId: 5
#   quoteAssetId: 13
#   symbolCategoryId: 1
#   description: "Euro vs Polish Zloty"
# }
# symbol {
#   symbolId: 1023
#   symbolName: "EURRUB"
#   enabled: false
#   baseAssetId: 5
#   quoteAssetId: 22
#   symbolCategoryId: 1
#   description: "Euro vs Russian Ruble"
# }
# symbol {
#   symbolId: 31
#   symbolName: "EURSEK"
#   enabled: true
#   baseAssetId: 5
#   quoteAssetId: 14
#   symbolCategoryId: 1
#   description: "Euro vs Swedish Krona"
# }
# symbol {
#   symbolId: 1006
#   symbolName: "EURSGD"
#   enabled: true
#   baseAssetId: 5
#   quoteAssetId: 15
#   symbolCategoryId: 1
#   description: "Euro vs Singapore Dollar"
# }
# symbol {
#   symbolId: 1007
#   symbolName: "EURTRY"
#   enabled: true
#   baseAssetId: 5
#   quoteAssetId: 19
#   symbolCategoryId: 1
#   description: "Euro vs Turkish Lira"
# }
# symbol {
#   symbolId: 1008
#   symbolName: "EURZAR"
#   enabled: true
#   baseAssetId: 5
#   quoteAssetId: 20
#   symbolCategoryId: 1
#   description: "Euro vs South African Rand"
# }
# symbol {
#   symbolId: 16
#   symbolName: "GBPAUD"
#   enabled: true
#   baseAssetId: 6
#   quoteAssetId: 1
#   symbolCategoryId: 1
#   description: "British Pound vs Australian Dollar"
# }
# symbol {
#   symbolId: 19
#   symbolName: "GBPCAD"
#   enabled: true
#   baseAssetId: 6
#   quoteAssetId: 2
#   symbolCategoryId: 1
#   description: "British Pound vs Canadian Dollar"
# }
# symbol {
#   symbolId: 40
#   symbolName: "GBPCHF"
#   enabled: true
#   baseAssetId: 6
#   quoteAssetId: 3
#   symbolCategoryId: 1
#   description: "British Pound vs Swiss Franc"
# }
# symbol {
#   symbolId: 7
#   symbolName: "GBPJPY"
#   enabled: true
#   baseAssetId: 6
#   quoteAssetId: 9
#   symbolCategoryId: 1
#   description: "British Pound vs Japanese Yen"
# }
# symbol {
#   symbolId: 37
#   symbolName: "GBPNOK"
#   enabled: true
#   baseAssetId: 6
#   quoteAssetId: 11
#   symbolCategoryId: 1
#   description: "British Pound vs Norwegian Krone"
# }
# symbol {
#   symbolId: 25
#   symbolName: "GBPNZD"
#   enabled: true
#   baseAssetId: 6
#   quoteAssetId: 12
#   symbolCategoryId: 1
#   description: "British Pound vs New Zealand Dollar "
# }
# symbol {
#   symbolId: 32
#   symbolName: "GBPSGD"
#   enabled: true
#   baseAssetId: 6
#   quoteAssetId: 15
#   symbolCategoryId: 1
#   description: "Great Britain Pound vs Singapore Dollar"
# }
# symbol {
#   symbolId: 1021
#   symbolName: "GBPZAR"
#   enabled: false
#   baseAssetId: 6
#   quoteAssetId: 20
#   symbolCategoryId: 1
#   description: "British Pound vs South African rand"
# }
# symbol {
#   symbolId: 10000
#   symbolName: "AUS200"
#   enabled: true
#   baseAssetId: 25
#   quoteAssetId: 1
#   symbolCategoryId: 3
#   description: "Australian S&P/ASX 200 Index"
# }
# symbol {
#   symbolId: 10001
#   symbolName: "STOXX50"
#   enabled: true
#   baseAssetId: 26
#   quoteAssetId: 5
#   symbolCategoryId: 3
#   description: "EURO STOXX 50 Index"
# }
# symbol {
#   symbolId: 10002
#   symbolName: "F40"
#   enabled: true
#   baseAssetId: 27
#   quoteAssetId: 5
#   symbolCategoryId: 3
#   description: "French CAC 40 Index"
# }
# symbol {
#   symbolId: 10003
#   symbolName: "DE30"
#   enabled: true
#   baseAssetId: 28
#   quoteAssetId: 5
#   symbolCategoryId: 3
#   description: "German DAX 30 Index"
# }
# symbol {
#   symbolId: 10004
#   symbolName: "HK50"
#   enabled: true
#   baseAssetId: 29
#   quoteAssetId: 7
#   symbolCategoryId: 3
#   description: "Chinese Hang Seng 50 Index"
# }
# symbol {
#   symbolId: 10005
#   symbolName: "IT40"
#   enabled: true
#   baseAssetId: 30
#   quoteAssetId: 5
#   symbolCategoryId: 3
#   description: "Italian FTSE MIB Index"
# }
# symbol {
#   symbolId: 10006
#   symbolName: "JP225"
#   enabled: true
#   baseAssetId: 31
#   quoteAssetId: 9
#   symbolCategoryId: 3
#   description: "Japan Nikkei 225 Index"
# }
# symbol {
#   symbolId: 10007
#   symbolName: "AEX"
#   enabled: false
#   baseAssetId: 32
#   quoteAssetId: 5
#   symbolCategoryId: 3
#   description: "Netherlandish AEX 25 Index"
# }
# symbol {
#   symbolId: 10008
#   symbolName: "WIG20"
#   enabled: false
#   baseAssetId: 33
#   quoteAssetId: 13
#   symbolCategoryId: 3
#   description: "Poland WIG20 Index"
# }
# symbol {
#   symbolId: 10009
#   symbolName: "ES35"
#   enabled: true
#   baseAssetId: 34
#   quoteAssetId: 5
#   symbolCategoryId: 3
#   description: "Spanish IBEX 35 Index"
# }
# symbol {
#   symbolId: 10010
#   symbolName: "SMI"
#   enabled: false
#   baseAssetId: 35
#   quoteAssetId: 3
#   symbolCategoryId: 3
#   description: "Swiss Market Index"
# }
# symbol {
#   symbolId: 10011
#   symbolName: "UK100"
#   enabled: true
#   baseAssetId: 36
#   quoteAssetId: 6
#   symbolCategoryId: 3
#   description: "UK 100 Index"
# }
# symbol {
#   symbolId: 10012
#   symbolName: "US2000"
#   enabled: true
#   baseAssetId: 37
#   quoteAssetId: 16
#   symbolCategoryId: 3
#   description: "USA Russell 2000 Index"
# }
# symbol {
#   symbolId: 10013
#   symbolName: "US500"
#   enabled: true
#   baseAssetId: 38
#   quoteAssetId: 16
#   symbolCategoryId: 3
#   description: "USA S&P 500 Index"
# }
# symbol {
#   symbolId: 10014
#   symbolName: "USTEC"
#   enabled: true
#   baseAssetId: 39
#   quoteAssetId: 16
#   symbolCategoryId: 3
#   description: "USA NASDAQ 100 Index"
# }
# symbol {
#   symbolId: 10015
#   symbolName: "US30"
#   enabled: true
#   baseAssetId: 40
#   quoteAssetId: 16
#   symbolCategoryId: 3
#   description: "USA Dow Jones IA Index"
# }
# symbol {
#   symbolId: 1009
#   symbolName: "GBPDKK"
#   enabled: true
#   baseAssetId: 6
#   quoteAssetId: 4
#   symbolCategoryId: 1
#   description: "British Pound vs Danish Krone"
# }
# symbol {
#   symbolId: 1010
#   symbolName: "GBPSEK"
#   enabled: true
#   baseAssetId: 6
#   quoteAssetId: 14
#   symbolCategoryId: 1
#   description: "British Pound vs Swedish Krona"
# }
# symbol {
#   symbolId: 1014
#   symbolName: "NOKJPY"
#   enabled: true
#   baseAssetId: 11
#   quoteAssetId: 9
#   symbolCategoryId: 1
#   description: "Norwegian Krone vs Japanese Yen"
# }
# symbol {
#   symbolId: 1011
#   symbolName: "NOKSEK"
#   enabled: true
#   baseAssetId: 11
#   quoteAssetId: 14
#   symbolCategoryId: 1
#   description: "Norwegian Krone vs Swedish Krona"
# }
# symbol {
#   symbolId: 30
#   symbolName: "NZDCAD"
#   enabled: true
#   baseAssetId: 12
#   quoteAssetId: 2
#   symbolCategoryId: 1
#   description: "New Zealand Dollar vs Canadian Dollar"
# }
# symbol {
#   symbolId: 39
#   symbolName: "NZDCHF"
#   enabled: true
#   baseAssetId: 12
#   quoteAssetId: 3
#   symbolCategoryId: 1
#   description: "New Zealand Dollar vs Swiss Franc"
# }
# symbol {
#   symbolId: 21
#   symbolName: "NZDJPY"
#   enabled: true
#   baseAssetId: 12
#   quoteAssetId: 9
#   symbolCategoryId: 1
#   description: "New Zealand Dollar vs Japanese Yen"
# }
# symbol {
#   symbolId: 1025
#   symbolName: "NZDSGD"
#   enabled: false
#   baseAssetId: 12
#   quoteAssetId: 15
#   symbolCategoryId: 1
#   description: "New Zealand Dollar vs Singapore Dollar"
# }
# symbol {
#   symbolId: 12
#   symbolName: "NZDUSD"
#   enabled: true
#   baseAssetId: 12
#   quoteAssetId: 16
#   symbolCategoryId: 1
#   description: "New Zealand Dollar vs US Dollar"
# }
# symbol {
#   symbolId: 1015
#   symbolName: "SEKJPY"
#   enabled: true
#   baseAssetId: 14
#   quoteAssetId: 9
#   symbolCategoryId: 1
#   description: "Swedish Krona vs Japanese Yen"
# }
# symbol {
#   symbolId: 1016
#   symbolName: "SGDJPY"
#   enabled: true
#   baseAssetId: 15
#   quoteAssetId: 9
#   symbolCategoryId: 1
#   description: "Singapore Dollar vs Japanese Yen"
# }
# symbol {
#   symbolId: 1020
#   symbolName: "USDCNH"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 23
#   symbolCategoryId: 1
#   description: "US Dollar vs China Offshore Spot"
# }
# symbol {
#   symbolId: 1018
#   symbolName: "USDCZK"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 21
#   symbolCategoryId: 1
#   description: "US Dollar vs Czech Koruna"
# }
# symbol {
#   symbolId: 36
#   symbolName: "USDDKK"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 4
#   symbolCategoryId: 1
#   description: "US Dollar vs Danish Krone"
# }
# symbol {
#   symbolId: 1000
#   symbolName: "USDHKD"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 7
#   symbolCategoryId: 1
#   description: "US Dollar vs Hong Kong dollar"
# }
# symbol {
#   symbolId: 1017
#   symbolName: "USDHUF"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 8
#   symbolCategoryId: 1
#   description: "US Dollar vs Hungarian Forint"
# }
# symbol {
#   symbolId: 24
#   symbolName: "USDMXN"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 10
#   symbolCategoryId: 1
#   description: "US Dollar vs Mexican Peso"
# }
# symbol {
#   symbolId: 22
#   symbolName: "USDNOK"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 11
#   symbolCategoryId: 1
#   description: "US Dollar vs Norwegian Krone"
# }
# symbol {
#   symbolId: 35
#   symbolName: "USDPLN"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 13
#   symbolCategoryId: 1
#   description: "US Dollar vs Polish Zloty"
# }
# symbol {
#   symbolId: 1019
#   symbolName: "USDRUB"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 22
#   symbolCategoryId: 1
#   description: "US Dollar vs Russian Ruble"
# }
# symbol {
#   symbolId: 29
#   symbolName: "USDSEK"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 14
#   symbolCategoryId: 1
#   description: "US Dollar vs Swedish Krona"
# }
# symbol {
#   symbolId: 28
#   symbolName: "USDSGD"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 15
#   symbolCategoryId: 1
#   description: "US Dollar vs Singapore Dollar"
# }
# symbol {
#   symbolId: 1026
#   symbolName: "USDTHB"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 24
#   symbolCategoryId: 1
#   description: "US Dollar vs Thai Bhat"
# }
# symbol {
#   symbolId: 1012
#   symbolName: "USDTRY"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 19
#   symbolCategoryId: 1
#   description: "US Dollar vs Turkish Lira"
# }
# symbol {
#   symbolId: 1013
#   symbolName: "USDZAR"
#   enabled: true
#   baseAssetId: 16
#   quoteAssetId: 20
#   symbolCategoryId: 1
#   description: "US Dollar vs South African Rand"
# }
# symbol {
#   symbolId: 10021
#   symbolName: "BRENT"
#   enabled: false
#   baseAssetId: 46
#   quoteAssetId: 16
#   symbolCategoryId: 4
#   description: "Brent Crude Oil"
# }
# symbol {
#   symbolId: 10022
#   symbolName: "WTI"
#   enabled: false
#   baseAssetId: 47
#   quoteAssetId: 16
#   symbolCategoryId: 4
#   description: "WTI Light Crude Oil"
# }
# symbol {
#   symbolId: 10018
#   symbolName: "XBRUSD"
#   enabled: true
#   baseAssetId: 43
#   quoteAssetId: 16
#   symbolCategoryId: 4
#   description: "Brent Crude Oil"
# }
# symbol {
#   symbolId: 10019
#   symbolName: "XTIUSD"
#   enabled: true
#   baseAssetId: 44
#   quoteAssetId: 16
#   symbolCategoryId: 4
#   description: "WTI Light Crude Oil"
# }
# symbol {
#   symbolId: 10023
#   symbolName: "EURUSDt"
#   enabled: false
#   baseAssetId: 48
#   quoteAssetId: 16
#   symbolCategoryId: 1
#   description: "Euro vs US Dollar"
# }
# symbol {
#   symbolId: 10024
#   symbolName: "DE30t"
#   enabled: false
#   baseAssetId: 49
#   quoteAssetId: 5
#   symbolCategoryId: 3
#   description: "German DAX 30 Index"
# }
# symbol {
#   symbolId: 10025
#   symbolName: "CHINA50"
#   enabled: true
#   baseAssetId: 55
#   quoteAssetId: 16
#   symbolCategoryId: 3
#   description: "FTSE China A50 Index"
# }
# symbol {
#   symbolId: 10026
#   symbolName: "BTCUSD"
#   enabled: true
#   baseAssetId: 50
#   quoteAssetId: 16
#   symbolCategoryId: 8
#   description: "Bitcoin"
# }
# symbol {
#   symbolId: 10027
#   symbolName: "DSHUSD"
#   enabled: true
#   baseAssetId: 51
#   quoteAssetId: 16
#   symbolCategoryId: 8
#   description: "Dashcoin US Dollar"
# }
# symbol {
#   symbolId: 10028
#   symbolName: "BCHUSD"
#   enabled: true
#   baseAssetId: 52
#   quoteAssetId: 16
#   symbolCategoryId: 8
#   description: "Bitcoin Cash US Dollar"
# }
# symbol {
#   symbolId: 10029
#   symbolName: "ETHUSD"
#   enabled: true
#   baseAssetId: 53
#   quoteAssetId: 16
#   symbolCategoryId: 8
#   description: "Etherimum US Dollar"
# }
# symbol {
#   symbolId: 10030
#   symbolName: "LTCUSD"
#   enabled: true
#   baseAssetId: 54
#   quoteAssetId: 16
#   symbolCategoryId: 8
#   description: "Litecoin US Dollar"
# }
# symbol {
#   symbolId: 10031
#   symbolName: "GBPTRY"
#   enabled: true
#   baseAssetId: 6
#   quoteAssetId: 19
#   symbolCategoryId: 1
#   description: "Great Britain Pound vs Turkish Lira"
# }
# symbol {
#   symbolId: 10033
#   symbolName: "CA60"
#   enabled: true
#   baseAssetId: 56
#   quoteAssetId: 2
#   symbolCategoryId: 3
#   description: "Canada 60 Index"
# }
# symbol {
#   symbolId: 10034
#   symbolName: "TecDE30"
#   enabled: true
#   baseAssetId: 57
#   quoteAssetId: 5
#   symbolCategoryId: 3
#   description: "Germany Tech 30 Index"
# }
# symbol {
#   symbolId: 10035
#   symbolName: "MidDE60"
#   enabled: true
#   baseAssetId: 58
#   quoteAssetId: 5
#   symbolCategoryId: 3
#   description: "Germany Mid 60 Index"
# }
# symbol {
#   symbolId: 10036
#   symbolName: "NETH25"
#   enabled: true
#   baseAssetId: 59
#   quoteAssetId: 5
#   symbolCategoryId: 3
#   description: "Netherlands 25 Index"
# }
# symbol {
#   symbolId: 10037
#   symbolName: "SWI20"
#   enabled: true
#   baseAssetId: 60
#   quoteAssetId: 3
#   symbolCategoryId: 3
#   description: "Switzerland 20 Index"
# }
# symbol {
#   symbolId: 10038
#   symbolName: "SG30"
#   enabled: false
#   baseAssetId: 61
#   quoteAssetId: 15
#   symbolCategoryId: 3
#   description: "Singpore 30 Index"
# }
# symbol {
#   symbolId: 10039
#   symbolName: "CHINAH"
#   enabled: true
#   baseAssetId: 62
#   quoteAssetId: 7
#   symbolCategoryId: 3
#   description: "Hong Kong China H-shares Index"
# }
# symbol {
#   symbolId: 10040
#   symbolName: "NOR25"
#   enabled: true
#   baseAssetId: 63
#   quoteAssetId: 11
#   symbolCategoryId: 3
#   description: "Norway 25 Index"
# }
# symbol {
#   symbolId: 10041
#   symbolName: "SA40"
#   enabled: true
#   baseAssetId: 64
#   quoteAssetId: 20
#   symbolCategoryId: 3
#   description: "South Africa 40 Index"
# }
# symbol {
#   symbolId: 10042
#   symbolName: "SE30"
#   enabled: true
#   baseAssetId: 65
#   quoteAssetId: 14
#   symbolCategoryId: 3
#   description: "Sweden 30 Index"
# }
# symbol {
#   symbolId: 10043
#   symbolName: "USCrude100"
#   enabled: false
#   baseAssetId: 66
#   quoteAssetId: 16
#   symbolCategoryId: 4
#   description: "XTIUSD $100 Rebased"
# }
# symbol {
#   symbolId: 10044
#   symbolName: "UKBrent100"
#   enabled: false
#   baseAssetId: 67
#   quoteAssetId: 16
#   symbolCategoryId: 4
#   description: "XBRUSD $100 Rebased"
# }
# symbol {
#   symbolId: 10045
#   symbolName: "MidDE50"
#   enabled: true
#   baseAssetId: 68
#   quoteAssetId: 5
#   symbolCategoryId: 3
#   description: "Germany Mid 50 Index"
# }
# symbol {
#   symbolId: 10046
#   symbolName: "DE40"
#   enabled: true
#   baseAssetId: 69
#   quoteAssetId: 5
#   symbolCategoryId: 3
#   description: "Germany DAX 40 Index"
# }
# symbol {
#   symbolId: 10047
#   symbolName: "XAUCHF"
#   enabled: true
#   baseAssetId: 18
#   quoteAssetId: 3
#   symbolCategoryId: 2
#   description: "Gold vs Swiss Franc"
# }
# symbol {
#   symbolId: 10048
#   symbolName: "XAUGBP"
#   enabled: true
#   baseAssetId: 18
#   quoteAssetId: 6
#   symbolCategoryId: 2
#   description: "Gold vs British Pound"
# }
# symbol {
#   symbolId: 10049
#   symbolName: "XAUJPY"
#   enabled: true
#   baseAssetId: 18
#   quoteAssetId: 9
#   symbolCategoryId: 2
#   description: "Gold vs Japanese Yen"
# }
# symbol {
#   symbolId: 10050
#   symbolName: "XAGAUD"
#   enabled: true
#   baseAssetId: 17
#   quoteAssetId: 1
#   symbolCategoryId: 2
#   description: "Silver vs Australian Dollar"
# }
#
#
# Symbols received
# Message received:
#  ctidTraderAccountId: 24136091
# period: D1
# timestamp: 1677880800000
# trendbar {
#   volume: 118582
#   low: 110103
#   deltaOpen: 471
#   deltaClose: 65
#   deltaHigh: 598
#   utcTimestampInMinutes: 27463500
# }
# trendbar {
#   volume: 136869
#   low: 109610
#   deltaOpen: 543
#   deltaClose: 636
#   deltaHigh: 848
#   utcTimestampInMinutes: 27464940
# }
# trendbar {
#   volume: 117124
#   low: 109640
#   deltaOpen: 598
#   deltaClose: 417
#   deltaHigh: 801
#   utcTimestampInMinutes: 27466380
# }
# trendbar {
#   volume: 125945
#   low: 109660
#   deltaOpen: 396
#   deltaClose: 310
#   deltaHigh: 480
#   utcTimestampInMinutes: 27467820
# }
# trendbar {
#   volume: 129440
#   low: 109810
#   deltaOpen: 131
#   deltaClose: 25
#   deltaHigh: 568
#   utcTimestampInMinutes: 27469260
# }
# trendbar {
#   volume: 149841
#   low: 109449
#   deltaOpen: 400
#   deltaClose: 415
#   deltaHigh: 547
#   utcTimestampInMinutes: 27473580
# }
# trendbar {
#   volume: 178884
#   low: 109698
#   deltaOpen: 106
#   deltaClose: 1164
#   deltaHigh: 1674
#   utcTimestampInMinutes: 27475020
# }
# trendbar {
#   volume: 163464
#   low: 110806
#   deltaOpen: 58
#   deltaClose: 774
#   deltaHigh: 905
#   utcTimestampInMinutes: 27476460
# }
# trendbar {
#   volume: 155191
#   low: 110610
#   deltaOpen: 961
#   deltaClose: 52
#   deltaHigh: 1239
#   utcTimestampInMinutes: 27477900
# }
# trendbar {
#   volume: 130273
#   low: 110281
#   deltaOpen: 358
#   deltaClose: 210
#   deltaHigh: 483
#   utcTimestampInMinutes: 27479340
# }
# trendbar {
#   volume: 104900
#   low: 109607
#   deltaOpen: 718
#   deltaClose: 115
#   deltaHigh: 938
#   utcTimestampInMinutes: 27483660
# }
# trendbar {
#   volume: 113582
#   low: 109000
#   deltaOpen: 704
#   deltaClose: 57
#   deltaHigh: 887
#   utcTimestampInMinutes: 27485100
# }
# trendbar {
#   volume: 141915
#   low: 108743
#   deltaOpen: 305
#   deltaClose: 221
#   deltaHigh: 637
#   utcTimestampInMinutes: 27486540
# }
# trendbar {
#   volume: 134163
#   low: 108649
#   deltaOpen: 266
#   deltaClose: 152
#   deltaHigh: 736
#   utcTimestampInMinutes: 27487980
# }
# trendbar {
#   volume: 116554
#   low: 108365
#   deltaOpen: 393
#   deltaClose: 396
#   deltaHigh: 553
#   utcTimestampInMinutes: 27489420
# }
# trendbar {
#   volume: 119231
#   low: 108728
#   deltaOpen: 490
#   deltaClose: 107
#   deltaHigh: 605
#   utcTimestampInMinutes: 27493740
# }
# trendbar {
#   volume: 142991
#   low: 108214
#   deltaOpen: 607
#   deltaClose: 46
#   deltaHigh: 822
#   utcTimestampInMinutes: 27495180
# }
# trendbar {
#   volume: 124749
#   low: 108089
#   deltaOpen: 181
#   deltaClose: 828
#   deltaHigh: 853
#   utcTimestampInMinutes: 27496620
# }
# trendbar {
#   volume: 149139
#   low: 107576
#   deltaOpen: 1187
#   deltaClose: 717
#   deltaHigh: 1656
#   utcTimestampInMinutes: 27498060
# }
# trendbar {
#   volume: 77837
#   low: 107965
#   deltaOpen: 310
#   deltaClose: 173
#   deltaHigh: 337
#   utcTimestampInMinutes: 27499500
# }
# trendbar {
#   volume: 86486
#   low: 107700
#   deltaOpen: 337
#   deltaClose: 109
#   deltaHigh: 517
#   utcTimestampInMinutes: 27503820
# }
# trendbar {
#   volume: 125314
#   low: 107613
#   deltaOpen: 169
#   deltaClose: 277
#   deltaHigh: 533
#   utcTimestampInMinutes: 27505260
# }
# trendbar {
#   volume: 145881
#   low: 107830
#   deltaOpen: 44
#   deltaClose: 713
#   deltaHigh: 840
#   utcTimestampInMinutes: 27506700
# }
# trendbar {
#   volume: 150524
#   low: 108237
#   deltaOpen: 251
#   deltaClose: 84
#   deltaHigh: 1126
#   utcTimestampInMinutes: 27508140
# }
# trendbar {
#   volume: 148081
#   low: 107708
#   deltaOpen: 664
#   deltaClose: 253
#   deltaHigh: 808
#   utcTimestampInMinutes: 27509580
# }
# trendbar {
#   volume: 181239
#   low: 106968
#   deltaOpen: 1110
#   deltaClose: 149
#   deltaHigh: 1170
#   utcTimestampInMinutes: 27513900
# }
# trendbar {
#   volume: 151037
#   low: 106359
#   deltaOpen: 756
#   deltaClose: 14
#   deltaHigh: 1028
#   utcTimestampInMinutes: 27515340
# }
# trendbar {
#   volume: 170919
#   low: 105146
#   deltaOpen: 1229
#   deltaClose: 440
#   deltaHigh: 1402
#   utcTimestampInMinutes: 27516780
# }
# trendbar {
#   volume: 193961
#   low: 104714
#   deltaOpen: 891
#   deltaClose: 269
#   deltaHigh: 934
#   utcTimestampInMinutes: 27518220
# }
# trendbar {
#   volume: 163489
#   low: 104912
#   deltaOpen: 61
#   deltaClose: 508
#   deltaHigh: 1017
#   utcTimestampInMinutes: 27519660
# }
# trendbar {
#   volume: 140287
#   low: 104903
#   deltaOpen: 711
#   deltaClose: 171
#   deltaHigh: 781
#   utcTimestampInMinutes: 27523980
# }
# trendbar {
#   volume: 137682
#   low: 104923
#   deltaOpen: 101
#   deltaClose: 270
#   deltaHigh: 854
#   utcTimestampInMinutes: 27525420
# }
# trendbar {
#   volume: 155036
#   low: 105062
#   deltaOpen: 131
#   deltaClose: 1131
#   deltaHigh: 1249
#   utcTimestampInMinutes: 27526860
# }
# trendbar {
#   volume: 194405
#   low: 104928
#   deltaOpen: 1268
#   deltaClose: 464
#   deltaHigh: 1492
#   utcTimestampInMinutes: 27528300
# }
# trendbar {
#   volume: 222496
#   low: 104828
#   deltaOpen: 581
#   deltaClose: 628
#   deltaHigh: 1162
#   utcTimestampInMinutes: 27529740
# }
# trendbar {
#   volume: 180868
#   low: 104952
#   deltaOpen: 453
#   deltaClose: 630
#   deltaHigh: 974
#   utcTimestampInMinutes: 27534060
# }
# trendbar {
#   volume: 188040
#   low: 105255
#   deltaOpen: 327
#   deltaClose: 44
#   deltaHigh: 600
#   utcTimestampInMinutes: 27535500
# }
# trendbar {
#   volume: 189288
#   low: 105020
#   deltaOpen: 252
#   deltaClose: 117
#   deltaHigh: 752
#   utcTimestampInMinutes: 27536940
# }
# trendbar {
#   volume: 204473
#   low: 103541
#   deltaOpen: 1648
#   deltaClose: 254
#   deltaHigh: 1753
#   utcTimestampInMinutes: 27538380
# }
# trendbar {
#   volume: 152882
#   low: 103495
#   deltaOpen: 295
#   deltaClose: 587
#   deltaHigh: 703
#   utcTimestampInMinutes: 27539820
# }
# trendbar {
#   volume: 132024
#   low: 103891
#   deltaOpen: 187
#   deltaClose: 451
#   deltaHigh: 541
#   utcTimestampInMinutes: 27544140
# }
# trendbar {
#   volume: 153542
#   low: 104286
#   deltaOpen: 61
#   deltaClose: 1219
#   deltaHigh: 1272
#   utcTimestampInMinutes: 27545580
# }
# trendbar {
#   volume: 140023
#   low: 104604
#   deltaOpen: 866
#   deltaClose: 4
#   deltaHigh: 1035
#   utcTimestampInMinutes: 27547020
# }
# trendbar {
#   volume: 190968
#   low: 104610
#   deltaOpen: 30
#   deltaClose: 1224
#   deltaHigh: 1462
#   utcTimestampInMinutes: 27548460
# }
# trendbar {
#   volume: 150961
#   low: 105329
#   deltaOpen: 507
#   deltaClose: 293
#   deltaHigh: 656
#   utcTimestampInMinutes: 27549900
# }
# trendbar {
#   volume: 138222
#   low: 105571
#   deltaOpen: 35
#   deltaClose: 1350
#   deltaHigh: 1403
#   utcTimestampInMinutes: 27554220
# }
# trendbar {
#   volume: 147955
#   low: 106609
#   deltaOpen: 287
#   deltaClose: 750
#   deltaHigh: 877
#   utcTimestampInMinutes: 27555660
# }
# trendbar {
#   volume: 150865
#   low: 106423
#   deltaOpen: 942
#   deltaClose: 363
#   deltaHigh: 968
#   utcTimestampInMinutes: 27557100
# }
# trendbar {
#   volume: 129404
#   low: 106625
#   deltaOpen: 183
#   deltaClose: 667
#   deltaHigh: 691
#   utcTimestampInMinutes: 27558540
# }
# trendbar {
#   volume: 129095
#   low: 106970
#   deltaOpen: 254
#   deltaClose: 378
#   deltaHigh: 680
#   utcTimestampInMinutes: 27559980
# }
# trendbar {
#   volume: 97855
#   low: 107262
#   deltaOpen: 90
#   deltaClose: 536
#   deltaHigh: 608
#   utcTimestampInMinutes: 27564300
# }
# trendbar {
#   volume: 170599
#   low: 106791
#   deltaOpen: 982
#   deltaClose: 533
#   deltaHigh: 1003
#   utcTimestampInMinutes: 27565740
# }
# trendbar {
#   volume: 148868
#   low: 106274
#   deltaOpen: 1081
#   deltaClose: 253
#   deltaHigh: 1120
#   utcTimestampInMinutes: 27567180
# }
# trendbar {
#   volume: 128262
#   low: 106447
#   deltaOpen: 9
#   deltaClose: 1015
#   deltaHigh: 1055
#   utcTimestampInMinutes: 27568620
# }
# trendbar {
#   volume: 118967
#   low: 107042
#   deltaOpen: 416
#   deltaClose: 156
#   deltaHigh: 600
#   utcTimestampInMinutes: 27570060
# }
# trendbar {
#   volume: 116066
#   low: 106840
#   deltaOpen: 376
#   deltaClose: 118
#   deltaHigh: 681
#   utcTimestampInMinutes: 27574380
# }
# trendbar {
#   volume: 145409
#   low: 106521
#   deltaOpen: 465
#   deltaClose: 528
#   deltaHigh: 623
#   utcTimestampInMinutes: 27575820
# }
# trendbar {
#   volume: 140255
#   low: 106715
#   deltaOpen: 337
#   deltaClose: 448
#   deltaHigh: 770
#   utcTimestampInMinutes: 27577260
# }
# trendbar {
#   volume: 167198
#   low: 106113
#   deltaOpen: 1053
#   deltaClose: 67
#   deltaHigh: 1627
#   utcTimestampInMinutes: 27578700
# }
# trendbar {
#   volume: 177568
#   low: 105059
#   deltaOpen: 1113
#   deltaClose: 131
#   deltaHigh: 1364
#   utcTimestampInMinutes: 27580140
# }
# trendbar {
#   volume: 210768
#   low: 103999
#   deltaOpen: 1173
#   deltaClose: 81
#   deltaHigh: 1201
#   utcTimestampInMinutes: 27584460
# }
# trendbar {
#   volume: 209067
#   low: 103970
#   deltaOpen: 106
#   deltaClose: 205
#   deltaHigh: 878
#   utcTimestampInMinutes: 27585900
# }
# trendbar {
#   volume: 248477
#   low: 103590
#   deltaOpen: 524
#   deltaClose: 882
#   deltaHigh: 1489
#   utcTimestampInMinutes: 27587340
# }
# trendbar {
#   volume: 249002
#   low: 103809
#   deltaOpen: 641
#   deltaClose: 1696
#   deltaHigh: 2205
#   utcTimestampInMinutes: 27588780
# }
# trendbar {
#   volume: 226235
#   low: 104444
#   deltaOpen: 1050
#   deltaClose: 516
#   deltaHigh: 1160
#   utcTimestampInMinutes: 27590220
# }
# trendbar {
#   volume: 142234
#   low: 104748
#   deltaOpen: 31
#   deltaClose: 361
#   deltaHigh: 712
#   utcTimestampInMinutes: 27594540
# }
# trendbar {
#   volume: 153196
#   low: 105071
#   deltaOpen: 27
#   deltaClose: 276
#   deltaHigh: 756
#   utcTimestampInMinutes: 27595980
# }
# trendbar {
#   volume: 185578
#   low: 104691
#   deltaOpen: 629
#   deltaClose: 997
#   deltaHigh: 1365
#   utcTimestampInMinutes: 27597420
# }
# trendbar {
#   volume: 214285
#   low: 104829
#   deltaOpen: 831
#   deltaClose: 382
#   deltaHigh: 981
#   utcTimestampInMinutes: 27598860
# }
# trendbar {
#   volume: 160600
#   low: 105121
#   deltaOpen: 113
#   deltaClose: 428
#   deltaHigh: 592
#   utcTimestampInMinutes: 27600300
# }
# trendbar {
#   volume: 158599
#   low: 105488
#   deltaOpen: 0
#   deltaClose: 331
#   deltaHigh: 661
#   utcTimestampInMinutes: 27604620
# }
# trendbar {
#   volume: 170339
#   low: 105036
#   deltaOpen: 817
#   deltaClose: 171
#   deltaHigh: 1026
#   utcTimestampInMinutes: 27606060
# }
# trendbar {
#   volume: 179297
#   low: 104352
#   deltaOpen: 838
#   deltaClose: 61
#   deltaHigh: 1003
#   utcTimestampInMinutes: 27607500
# }
# trendbar {
#   volume: 181648
#   low: 103827
#   deltaOpen: 578
#   deltaClose: 1008
#   deltaHigh: 1058
#   utcTimestampInMinutes: 27608940
# }
# trendbar {
#   volume: 183714
#   low: 103655
#   deltaOpen: 1139
#   deltaClose: 620
#   deltaHigh: 1195
#   utcTimestampInMinutes: 27610380
# }
# trendbar {
#   volume: 116266
#   low: 104168
#   deltaOpen: 24
#   deltaClose: 59
#   deltaHigh: 460
#   utcTimestampInMinutes: 27614700
# }
# trendbar {
#   volume: 182294
#   low: 102352
#   deltaOpen: 1850
#   deltaClose: 289
#   deltaHigh: 2138
#   utcTimestampInMinutes: 27616140
# }
# trendbar {
#   volume: 200674
#   low: 101618
#   deltaOpen: 1064
#   deltaClose: 195
#   deltaHigh: 1147
#   utcTimestampInMinutes: 27617580
# }
# trendbar {
#   volume: 167072
#   low: 101442
#   deltaOpen: 365
#   deltaClose: 172
#   deltaHigh: 768
#   utcTimestampInMinutes: 27619020
# }
# trendbar {
#   volume: 182705
#   low: 100719
#   deltaOpen: 911
#   deltaClose: 1142
#   deltaHigh: 1196
#   utcTimestampInMinutes: 27620460
# }
# trendbar {
#   volume: 169232
#   low: 100338
#   deltaOpen: 1450
#   deltaClose: 69
#   deltaHigh: 1512
#   utcTimestampInMinutes: 27624780
# }
# trendbar {
#   volume: 190209
#   low: 100000
#   deltaOpen: 390
#   deltaClose: 360
#   deltaHigh: 738
#   utcTimestampInMinutes: 27626220
# }
# trendbar {
#   volume: 209458
#   low: 99980
#   deltaOpen: 416
#   deltaClose: 596
#   deltaHigh: 1241
#   utcTimestampInMinutes: 27627660
# }
# trendbar {
#   volume: 217441
#   low: 99523
#   deltaOpen: 1081
#   deltaClose: 685
#   deltaHigh: 1081
#   utcTimestampInMinutes: 27629100
# }
# trendbar {
#   volume: 173907
#   low: 100068
#   deltaOpen: 59
#   deltaClose: 810
#   deltaHigh: 911
#   utcTimestampInMinutes: 27630540
# }
# trendbar {
#   volume: 157618
#   low: 100786
#   deltaOpen: 25
#   deltaClose: 653
#   deltaHigh: 1227
#   utcTimestampInMinutes: 27634860
# }
# trendbar {
#   volume: 169044
#   low: 101197
#   deltaOpen: 181
#   deltaClose: 1032
#   deltaHigh: 1497
#   utcTimestampInMinutes: 27636300
# }
# trendbar {
#   volume: 155953
#   low: 101555
#   deltaOpen: 672
#   deltaClose: 264
#   deltaHigh: 1177
#   utcTimestampInMinutes: 27637740
# }
# trendbar {
#   volume: 183461
#   low: 101535
#   deltaOpen: 207
#   deltaClose: 744
#   deltaHigh: 1245
#   utcTimestampInMinutes: 27639180
# }
# trendbar {
#   volume: 171926
#   low: 101298
#   deltaOpen: 960
#   deltaClose: 853
#   deltaHigh: 1257
#   utcTimestampInMinutes: 27640620
# }
# trendbar {
#   volume: 165496
#   low: 101791
#   deltaOpen: 297
#   deltaClose: 392
#   deltaHigh: 787
#   utcTimestampInMinutes: 27644940
# }
# trendbar {
#   volume: 144315
#   low: 101076
#   deltaOpen: 1076
#   deltaClose: 101
#   deltaHigh: 1424
#   utcTimestampInMinutes: 27646380
# }
# trendbar {
#   volume: 157253
#   low: 100966
#   deltaOpen: 176
#   deltaClose: 1023
#   deltaHigh: 1241
#   utcTimestampInMinutes: 27647820
# }
# trendbar {
#   volume: 189737
#   low: 101140
#   deltaOpen: 856
#   deltaClose: 824
#   deltaHigh: 1203
#   utcTimestampInMinutes: 27649260
# }
# trendbar {
#   volume: 180430
#   low: 101461
#   deltaOpen: 511
#   deltaClose: 800
#   deltaHigh: 1079
#   utcTimestampInMinutes: 27650700
# }
# trendbar {
#   volume: 163663
#   low: 102055
#   deltaOpen: 79
#   deltaClose: 550
#   deltaHigh: 698
#   utcTimestampInMinutes: 27655020
# }
# trendbar {
#   volume: 199515
#   low: 101635
#   deltaOpen: 958
#   deltaClose: 25
#   deltaHigh: 1305
#   utcTimestampInMinutes: 27656460
# }
# trendbar {
#   volume: 173628
#   low: 101229
#   deltaOpen: 419
#   deltaClose: 458
#   deltaHigh: 869
#   utcTimestampInMinutes: 27657900
# }
# trendbar {
#   volume: 156624
#   low: 101546
#   deltaOpen: 106
#   deltaClose: 908
#   deltaHigh: 993
#   utcTimestampInMinutes: 27659340
# }
# trendbar {
#   volume: 152681
#   low: 101417
#   deltaOpen: 1036
#   deltaClose: 369
#   deltaHigh: 1106
#   utcTimestampInMinutes: 27660780
# }
# trendbar {
#   volume: 132287
#   low: 101593
#   deltaOpen: 146
#   deltaClose: 344
#   deltaHigh: 627
#   utcTimestampInMinutes: 27665100
# }
# trendbar {
#   volume: 108205
#   low: 101886
#   deltaOpen: 28
#   deltaClose: 246
#   deltaHigh: 589
#   utcTimestampInMinutes: 27666540
# }
# trendbar {
#   volume: 148967
#   low: 102022
#   deltaOpen: 99
#   deltaClose: 956
#   deltaHigh: 1664
#   utcTimestampInMinutes: 27667980
# }
# trendbar {
#   volume: 155013
#   low: 102755
#   deltaOpen: 236
#   deltaClose: 442
#   deltaHigh: 889
#   utcTimestampInMinutes: 27669420
# }
# trendbar {
#   volume: 132422
#   low: 102383
#   deltaOpen: 773
#   deltaClose: 208
#   deltaHigh: 893
#   utcTimestampInMinutes: 27670860
# }
# trendbar {
#   volume: 123011
#   low: 101546
#   deltaOpen: 1001
#   deltaClose: 46
#   deltaHigh: 1137
#   utcTimestampInMinutes: 27675180
# }
# trendbar {
#   volume: 136319
#   low: 101225
#   deltaOpen: 386
#   deltaClose: 480
#   deltaHigh: 721
#   utcTimestampInMinutes: 27676620
# }
# trendbar {
#   volume: 161475
#   low: 101454
#   deltaOpen: 196
#   deltaClose: 320
#   deltaHigh: 574
#   utcTimestampInMinutes: 27678060
# }
# trendbar {
#   volume: 151928
#   low: 100797
#   deltaOpen: 971
#   deltaClose: 69
#   deltaHigh: 1134
#   utcTimestampInMinutes: 27679500
# }
# trendbar {
#   volume: 135594
#   low: 100319
#   deltaOpen: 503
#   deltaClose: 74
#   deltaHigh: 636
#   utcTimestampInMinutes: 27680940
# }
# trendbar {
#   volume: 146644
#   low: 99263
#   deltaOpen: 1085
#   deltaClose: 159
#   deltaHigh: 1203
#   utcTimestampInMinutes: 27685260
# }
# trendbar {
#   volume: 170900
#   low: 99004
#   deltaOpen: 414
#   deltaClose: 673
#   deltaHigh: 1178
#   utcTimestampInMinutes: 27686700
# }
# trendbar {
#   volume: 145566
#   low: 99102
#   deltaOpen: 566
#   deltaClose: 577
#   deltaHigh: 886
#   utcTimestampInMinutes: 27688140
# }
# trendbar {
#   volume: 148729
#   low: 99491
#   deltaOpen: 133
#   deltaClose: 251
#   deltaHigh: 845
#   utcTimestampInMinutes: 27689580
# }
# trendbar {
#   volume: 157589
#   low: 99468
#   deltaOpen: 264
#   deltaClose: 184
#   deltaHigh: 1431
#   utcTimestampInMinutes: 27691020
# }
# trendbar {
#   volume: 168342
#   low: 99141
#   deltaOpen: 484
#   deltaClose: 836
#   deltaHigh: 1150
#   utcTimestampInMinutes: 27695340
# }
# trendbar {
#   volume: 175659
#   low: 99820
#   deltaOpen: 107
#   deltaClose: 331
#   deltaHigh: 729
#   utcTimestampInMinutes: 27696780
# }
# trendbar {
#   volume: 170605
#   low: 99712
#   deltaOpen: 423
#   deltaClose: 812
#   deltaHigh: 1078
#   utcTimestampInMinutes: 27698220
# }
# trendbar {
#   volume: 174357
#   low: 99110
#   deltaOpen: 1389
#   deltaClose: 340
#   deltaHigh: 1434
#   utcTimestampInMinutes: 27699660
# }
# trendbar {
#   volume: 170003
#   low: 99409
#   deltaOpen: 27
#   deltaClose: 105
#   deltaHigh: 927
#   utcTimestampInMinutes: 27701100
# }
# trendbar {
#   volume: 125166
#   low: 98781
#   deltaOpen: 432
#   deltaClose: 533
#   deltaHigh: 658
#   utcTimestampInMinutes: 27705420
# }
# trendbar {
#   volume: 187357
#   low: 98640
#   deltaOpen: 586
#   deltaClose: 426
#   deltaHigh: 1223
#   utcTimestampInMinutes: 27706860
# }
# trendbar {
#   volume: 169567
#   low: 98757
#   deltaOpen: 279
#   deltaClose: 1306
#   deltaHigh: 1351
#   utcTimestampInMinutes: 27708300
# }
# trendbar {
#   volume: 186136
#   low: 99308
#   deltaOpen: 766
#   deltaClose: 676
#   deltaHigh: 991
#   utcTimestampInMinutes: 27709740
# }
# trendbar {
#   volume: 164708
#   low: 99943
#   deltaOpen: 0
#   deltaClose: 520
#   deltaHigh: 1190
#   utcTimestampInMinutes: 27711180
# }
# trendbar {
#   volume: 167146
#   low: 100600
#   deltaOpen: 430
#   deltaClose: 618
#   deltaHigh: 1378
#   utcTimestampInMinutes: 27715500
# }
# trendbar {
#   volume: 170717
#   low: 99670
#   deltaOpen: 1552
#   deltaClose: 2
#   deltaHigh: 2203
#   utcTimestampInMinutes: 27716940
# }
# trendbar {
#   volume: 192783
#   low: 99557
#   deltaOpen: 122
#   deltaClose: 238
#   deltaHigh: 680
#   utcTimestampInMinutes: 27718380
# }
# trendbar {
#   volume: 151211
#   low: 99559
#   deltaOpen: 175
#   deltaClose: 405
#   deltaHigh: 620
#   utcTimestampInMinutes: 27719820
# }
# trendbar {
#   volume: 165674
#   low: 99452
#   deltaOpen: 485
#   deltaClose: 675
#   deltaHigh: 914
#   utcTimestampInMinutes: 27721260
# }
# trendbar {
#   volume: 126524
#   low: 99661
#   deltaOpen: 405
#   deltaClose: 588
#   deltaHigh: 632
#   utcTimestampInMinutes: 27725580
# }
# trendbar {
#   volume: 157971
#   low: 99553
#   deltaOpen: 628
#   deltaClose: 144
#   deltaHigh: 953
#   utcTimestampInMinutes: 27727020
# }
# trendbar {
#   volume: 199835
#   low: 98134
#   deltaOpen: 1547
#   deltaClose: 235
#   deltaHigh: 1626
#   utcTimestampInMinutes: 27728460
# }
# trendbar {
#   volume: 230887
#   low: 98085
#   deltaOpen: 275
#   deltaClose: 256
#   deltaHigh: 991
#   utcTimestampInMinutes: 27729900
# }
# trendbar {
#   volume: 212493
#   low: 96682
#   deltaOpen: 1618
#   deltaClose: 213
#   deltaHigh: 1837
#   utcTimestampInMinutes: 27731340
# }
# trendbar {
#   volume: 302744
#   low: 95527
#   deltaOpen: 1180
#   deltaClose: 559
#   deltaHigh: 1572
#   utcTimestampInMinutes: 27735660
# }
# trendbar {
#   volume: 225756
#   low: 95693
#   deltaOpen: 386
#   deltaClose: 245
#   deltaHigh: 1014
#   utcTimestampInMinutes: 27737100
# }
# trendbar {
#   volume: 276780
#   low: 95362
#   deltaOpen: 554
#   deltaClose: 2003
#   deltaHigh: 2148
#   utcTimestampInMinutes: 27738540
# }
# trendbar {
#   volume: 250079
#   low: 96358
#   deltaOpen: 943
#   deltaClose: 1775
#   deltaHigh: 1793
#   utcTimestampInMinutes: 27739980
# }
# trendbar {
#   volume: 251879
#   low: 97349
#   deltaOpen: 823
#   deltaClose: 669
#   deltaHigh: 1191
#   utcTimestampInMinutes: 27741420
# }
# trendbar {
#   volume: 221048
#   low: 97528
#   deltaOpen: 257
#   deltaClose: 719
#   deltaHigh: 918
#   utcTimestampInMinutes: 27745740
# }
# trendbar {
#   volume: 209970
#   low: 98062
#   deltaOpen: 186
#   deltaClose: 1793
#   deltaHigh: 1934
#   utcTimestampInMinutes: 27747180
# }
# trendbar {
#   volume: 172066
#   low: 98348
#   deltaOpen: 1496
#   deltaClose: 510
#   deltaHigh: 1603
#   utcTimestampInMinutes: 27748620
# }
# trendbar {
#   volume: 194056
#   low: 97884
#   deltaOpen: 821
#   deltaClose: 27
#   deltaHigh: 1381
#   utcTimestampInMinutes: 27750060
# }
# trendbar {
#   volume: 176395
#   low: 97260
#   deltaOpen: 624
#   deltaClose: 138
#   deltaHigh: 908
#   utcTimestampInMinutes: 27751500
# }
# trendbar {
#   volume: 153198
#   low: 96816
#   deltaOpen: 500
#   deltaClose: 216
#   deltaHigh: 717
#   utcTimestampInMinutes: 27755820
# }
# trendbar {
#   volume: 184138
#   low: 96706
#   deltaOpen: 225
#   deltaClose: 342
#   deltaHigh: 1041
#   utcTimestampInMinutes: 27757260
# }
# trendbar {
#   volume: 179838
#   low: 96680
#   deltaOpen: 364
#   deltaClose: 344
#   deltaHigh: 668
#   utcTimestampInMinutes: 27758700
# }
# trendbar {
#   volume: 193752
#   low: 96316
#   deltaOpen: 699
#   deltaClose: 1457
#   deltaHigh: 1744
#   utcTimestampInMinutes: 27760140
# }
# trendbar {
#   volume: 199408
#   low: 97073
#   deltaOpen: 625
#   deltaClose: 132
#   deltaHigh: 1013
#   utcTimestampInMinutes: 27761580
# }
# trendbar {
#   volume: 161740
#   low: 97170
#   deltaOpen: 41
#   deltaClose: 1270
#   deltaHigh: 1351
#   utcTimestampInMinutes: 27765900
# }
# trendbar {
#   volume: 170318
#   low: 98128
#   deltaOpen: 187
#   deltaClose: 473
#   deltaHigh: 630
#   utcTimestampInMinutes: 27767340
# }
# trendbar {
#   volume: 161487
#   low: 97573
#   deltaOpen: 909
#   deltaClose: 148
#   deltaHigh: 1153
#   utcTimestampInMinutes: 27768780
# }
# trendbar {
#   volume: 182985
#   low: 97546
#   deltaOpen: 171
#   deltaClose: 331
#   deltaHigh: 909
#   utcTimestampInMinutes: 27770220
# }
# trendbar {
#   volume: 222390
#   low: 97050
#   deltaOpen: 778
#   deltaClose: 1538
#   deltaHigh: 1640
#   utcTimestampInMinutes: 27771660
# }
# trendbar {
#   volume: 223017
#   low: 98069
#   deltaOpen: 661
#   deltaClose: 662
#   deltaHigh: 925
#   utcTimestampInMinutes: 27775980
# }
# trendbar {
#   volume: 168567
#   low: 98486
#   deltaOpen: 254
#   deltaClose: 1192
#   deltaHigh: 1282
#   utcTimestampInMinutes: 27777420
# }
# trendbar {
#   volume: 182517
#   low: 99437
#   deltaOpen: 197
#   deltaClose: 1396
#   deltaHigh: 1449
#   utcTimestampInMinutes: 27778860
# }
# trendbar {
#   volume: 192832
#   low: 99576
#   deltaOpen: 1171
#   deltaClose: 73
#   deltaHigh: 1362
#   utcTimestampInMinutes: 27780300
# }
# trendbar {
#   volume: 174150
#   low: 99268
#   deltaOpen: 372
#   deltaClose: 397
#   deltaHigh: 714
#   utcTimestampInMinutes: 27781740
# }
# trendbar {
#   volume: 141265
#   low: 98729
#   deltaOpen: 744
#   deltaClose: 96
#   deltaHigh: 929
#   utcTimestampInMinutes: 27786060
# }
# trendbar {
#   volume: 161403
#   low: 98530
#   deltaOpen: 196
#   deltaClose: 209
#   deltaHigh: 1006
#   utcTimestampInMinutes: 27787500
# }
# trendbar {
#   volume: 175752
#   low: 98130
#   deltaOpen: 635
#   deltaClose: 14
#   deltaHigh: 1628
#   utcTimestampInMinutes: 27788940
# }
# trendbar {
#   volume: 177704
#   low: 97301
#   deltaOpen: 826
#   deltaClose: 198
#   deltaHigh: 1095
#   utcTimestampInMinutes: 27790380
# }
# trendbar {
#   volume: 201557
#   low: 97426
#   deltaOpen: 36
#   deltaClose: 2156
#   deltaHigh: 2239
#   utcTimestampInMinutes: 27791820
# }
# trendbar {
#   volume: 180674
#   low: 99026
#   deltaOpen: 9
#   deltaClose: 1184
#   deltaHigh: 1314
#   utcTimestampInMinutes: 27796200
# }
# trendbar {
#   volume: 160345
#   low: 99715
#   deltaOpen: 453
#   deltaClose: 1013
#   deltaHigh: 1250
#   utcTimestampInMinutes: 27797640
# }
# trendbar {
#   volume: 198343
#   low: 99929
#   deltaOpen: 797
#   deltaClose: 189
#   deltaHigh: 954
#   utcTimestampInMinutes: 27799080
# }
# trendbar {
#   volume: 216598
#   low: 99356
#   deltaOpen: 729
#   deltaClose: 2724
#   deltaHigh: 2864
#   utcTimestampInMinutes: 27800520
# }
# trendbar {
#   volume: 225056
#   low: 101631
#   deltaOpen: 399
#   deltaClose: 1894
#   deltaHigh: 2011
#   utcTimestampInMinutes: 27801960
# }
# trendbar {
#   volume: 202751
#   low: 102714
#   deltaOpen: 656
#   deltaClose: 542
#   deltaHigh: 872
#   utcTimestampInMinutes: 27806280
# }
# trendbar {
#   volume: 236483
#   low: 102801
#   deltaOpen: 461
#   deltaClose: 666
#   deltaHigh: 2014
#   utcTimestampInMinutes: 27807720
# }
# trendbar {
#   volume: 210364
#   low: 103309
#   deltaOpen: 171
#   deltaClose: 633
#   deltaHigh: 1077
#   utcTimestampInMinutes: 27809160
# }
# trendbar {
#   volume: 183109
#   low: 103053
#   deltaOpen: 879
#   deltaClose: 595
#   deltaHigh: 1014
#   utcTimestampInMinutes: 27810600
# }
# trendbar {
#   volume: 156187
#   low: 103137
#   deltaOpen: 455
#   deltaClose: 103
#   deltaHigh: 824
#   utcTimestampInMinutes: 27812040
# }
# trendbar {
#   volume: 158858
#   low: 102228
#   deltaOpen: 989
#   deltaClose: 178
#   deltaHigh: 1102
#   utcTimestampInMinutes: 27816360
# }
# trendbar {
#   volume: 140175
#   low: 102378
#   deltaOpen: 26
#   deltaClose: 646
#   deltaHigh: 704
#   utcTimestampInMinutes: 27817800
# }
# trendbar {
#   volume: 152506
#   low: 102966
#   deltaOpen: 53
#   deltaClose: 979
#   deltaHigh: 1086
#   utcTimestampInMinutes: 27819240
# }
# trendbar {
#   volume: 120898
#   low: 103820
#   deltaOpen: 139
#   deltaClose: 294
#   deltaHigh: 666
#   utcTimestampInMinutes: 27820680
# }
# trendbar {
#   volume: 135124
#   low: 103548
#   deltaOpen: 529
#   deltaClose: 387
#   deltaHigh: 745
#   utcTimestampInMinutes: 27822120
# }
# trendbar {
#   volume: 173178
#   low: 103302
#   deltaOpen: 405
#   deltaClose: 98
#   deltaHigh: 1665
#   utcTimestampInMinutes: 27826440
# }
# trendbar {
#   volume: 170737
#   low: 103201
#   deltaOpen: 177
#   deltaClose: 89
#   deltaHigh: 743
#   utcTimestampInMinutes: 27827880
# }
# trendbar {
#   volume: 186877
#   low: 102903
#   deltaOpen: 385
#   deltaClose: 1181
#   deltaHigh: 1385
#   utcTimestampInMinutes: 27829320
# }
# trendbar {
#   volume: 201730
#   low: 103934
#   deltaOpen: 110
#   deltaClose: 1324
#   deltaHigh: 1405
#   utcTimestampInMinutes: 27830760
# }
# trendbar {
#   volume: 181274
#   low: 104284
#   deltaOpen: 932
#   deltaClose: 1121
#   deltaHigh: 1166
#   utcTimestampInMinutes: 27832200
# }
# trendbar {
#   volume: 174532
#   low: 104802
#   deltaOpen: 457
#   deltaClose: 130
#   deltaHigh: 1147
#   utcTimestampInMinutes: 27836520
# }
# trendbar {
#   volume: 171442
#   low: 104594
#   deltaOpen: 248
#   deltaClose: 80
#   deltaHigh: 736
#   utcTimestampInMinutes: 27837960
# }
# trendbar {
#   volume: 175856
#   low: 104432
#   deltaOpen: 188
#   deltaClose: 628
#   deltaHigh: 1067
#   utcTimestampInMinutes: 27839400
# }
# trendbar {
#   volume: 155616
#   low: 104896
#   deltaOpen: 135
#   deltaClose: 654
#   deltaHigh: 753
#   utcTimestampInMinutes: 27840840
# }
# trendbar {
#   volume: 159659
#   low: 105036
#   deltaOpen: 454
#   deltaClose: 291
#   deltaHigh: 848
#   utcTimestampInMinutes: 27842280
# }
# trendbar {
#   volume: 138440
#   low: 105062
#   deltaOpen: 217
#   deltaClose: 321
#   deltaHigh: 738
#   utcTimestampInMinutes: 27846600
# }
# trendbar {
#   volume: 172954
#   low: 105280
#   deltaOpen: 33
#   deltaClose: 1044
#   deltaHigh: 1453
#   utcTimestampInMinutes: 27848040
# }
# trendbar {
#   volume: 179782
#   low: 106190
#   deltaOpen: 130
#   deltaClose: 626
#   deltaHigh: 762
#   utcTimestampInMinutes: 27849480
# }
# trendbar {
#   volume: 172639
#   low: 105923
#   deltaOpen: 880
#   deltaClose: 340
#   deltaHigh: 1443
#   utcTimestampInMinutes: 27850920
# }
# trendbar {
#   volume: 155426
#   low: 105842
#   deltaOpen: 392
#   deltaClose: 10
#   deltaHigh: 787
#   utcTimestampInMinutes: 27852360
# }
# trendbar {
#   volume: 133218
#   low: 105759
#   deltaOpen: 96
#   deltaClose: 314
#   deltaHigh: 821
#   utcTimestampInMinutes: 27856680
# }
# trendbar {
#   volume: 191084
#   low: 105790
#   deltaOpen: 260
#   deltaClose: 442
#   deltaHigh: 796
#   utcTimestampInMinutes: 27858120
# }
# trendbar {
#   volume: 139982
#   low: 105904
#   deltaOpen: 348
#   deltaClose: 134
#   deltaHigh: 548
#   utcTimestampInMinutes: 27859560
# }
# trendbar {
#   volume: 142292
#   low: 105733
#   deltaOpen: 313
#   deltaClose: 250
#   deltaHigh: 861
#   utcTimestampInMinutes: 27861000
# }
# trendbar {
#   volume: 133430
#   low: 105867
#   deltaOpen: 67
#   deltaClose: 293
#   deltaHigh: 464
#   utcTimestampInMinutes: 27862440
# }
# trendbar {
#   volume: 111721
#   low: 106115
#   deltaOpen: 241
#   deltaClose: 275
#   deltaHigh: 580
#   utcTimestampInMinutes: 27868200
# }
# trendbar {
#   volume: 118223
#   low: 106068
#   deltaOpen: 334
#   deltaClose: 57
#   deltaHigh: 678
#   utcTimestampInMinutes: 27869640
# }
# trendbar {
#   volume: 112748
#   low: 106084
#   deltaOpen: 0
#   deltaClose: 537
#   deltaHigh: 821
#   utcTimestampInMinutes: 27871080
# }
# trendbar {
#   volume: 134605
#   low: 106389
#   deltaOpen: 223
#   deltaClose: 659
#   deltaHigh: 743
#   utcTimestampInMinutes: 27872520
# }
# trendbar {
#   volume: 32241
#   low: 106508
#   deltaOpen: 442
#   deltaClose: 92
#   deltaHigh: 584
#   utcTimestampInMinutes: 27876840
# }
# trendbar {
#   volume: 171901
#   low: 105196
#   deltaOpen: 1454
#   deltaClose: 292
#   deltaHigh: 1640
#   utcTimestampInMinutes: 27878280
# }
# trendbar {
#   volume: 167839
#   low: 105409
#   deltaOpen: 64
#   deltaClose: 632
#   deltaHigh: 944
#   utcTimestampInMinutes: 27879720
# }
# trendbar {
#   volume: 158131
#   low: 105151
#   deltaOpen: 879
#   deltaClose: 66
#   deltaHigh: 1163
#   utcTimestampInMinutes: 27881160
# }
# trendbar {
#   volume: 154704
#   low: 104825
#   deltaOpen: 400
#   deltaClose: 1631
#   deltaHigh: 1656
#   utcTimestampInMinutes: 27882600
# }
# trendbar {
#   volume: 148203
#   low: 106371
#   deltaOpen: 34
#   deltaClose: 955
#   deltaHigh: 1235
#   utcTimestampInMinutes: 27886920
# }
# trendbar {
#   volume: 146522
#   low: 107120
#   deltaOpen: 164
#   deltaClose: 223
#   deltaHigh: 474
#   utcTimestampInMinutes: 27888360
# }
# trendbar {
#   volume: 124981
#   low: 107254
#   deltaOpen: 75
#   deltaClose: 311
#   deltaHigh: 510
#   utcTimestampInMinutes: 27889800
# }
# trendbar {
#   volume: 171858
#   low: 107275
#   deltaOpen: 273
#   deltaClose: 1236
#   deltaHigh: 1394
#   utcTimestampInMinutes: 27891240
# }
# trendbar {
#   volume: 148737
#   low: 107804
#   deltaOpen: 610
#   deltaClose: 519
#   deltaHigh: 876
#   utcTimestampInMinutes: 27892680
# }
# trendbar {
#   volume: 102082
#   low: 108016
#   deltaOpen: 286
#   deltaClose: 207
#   deltaHigh: 726
#   utcTimestampInMinutes: 27897000
# }
# trendbar {
#   volume: 150587
#   low: 107748
#   deltaOpen: 467
#   deltaClose: 135
#   deltaHigh: 946
#   utcTimestampInMinutes: 27898440
# }
# trendbar {
#   volume: 184042
#   low: 107662
#   deltaOpen: 220
#   deltaClose: 282
#   deltaHigh: 1214
#   utcTimestampInMinutes: 27899880
# }
# trendbar {
#   volume: 146377
#   low: 107825
#   deltaOpen: 82
#   deltaClose: 485
#   deltaHigh: 575
#   utcTimestampInMinutes: 27901320
# }
# trendbar {
#   volume: 118426
#   low: 108024
#   deltaOpen: 257
#   deltaClose: 525
#   deltaHigh: 566
#   utcTimestampInMinutes: 27902760
# }
# trendbar {
#   volume: 132042
#   low: 108462
#   deltaOpen: 195
#   deltaClose: 252
#   deltaHigh: 806
#   utcTimestampInMinutes: 27907080
# }
# trendbar {
#   volume: 115796
#   low: 108352
#   deltaOpen: 355
#   deltaClose: 530
#   deltaHigh: 628
#   utcTimestampInMinutes: 27908520
# }
# trendbar {
#   volume: 119951
#   low: 108572
#   deltaOpen: 301
#   deltaClose: 580
#   deltaHigh: 664
#   utcTimestampInMinutes: 27909960
# }
# trendbar {
#   volume: 119626
#   low: 108507
#   deltaOpen: 635
#   deltaClose: 405
#   deltaHigh: 789
#   utcTimestampInMinutes: 27911400
# }
# trendbar {
#   volume: 108778
#   low: 108379
#   deltaOpen: 526
#   deltaClose: 301
#   deltaHigh: 625
#   utcTimestampInMinutes: 27912840
# }
# trendbar {
#   volume: 119208
#   low: 108393
#   deltaOpen: 230
#   deltaClose: 126
#   deltaHigh: 745
#   utcTimestampInMinutes: 27917160
# }
# trendbar {
#   volume: 122868
#   low: 108022
#   deltaOpen: 454
#   deltaClose: 599
#   deltaHigh: 728
#   utcTimestampInMinutes: 27918600
# }
# trendbar {
#   volume: 132074
#   low: 108524
#   deltaOpen: 96
#   deltaClose: 1377
#   deltaHigh: 1482
#   utcTimestampInMinutes: 27920040
# }
# trendbar {
#   volume: 160589
#   low: 108854
#   deltaOpen: 1026
#   deltaClose: 254
#   deltaHigh: 1475
#   utcTimestampInMinutes: 27921480
# }
# trendbar {
#   volume: 147409
#   low: 107926
#   deltaOpen: 1166
#   deltaClose: 6
#   deltaHigh: 1475
#   utcTimestampInMinutes: 27922920
# }
# trendbar {
#   volume: 128591
#   low: 107095
#   deltaOpen: 728
#   deltaClose: 162
#   deltaHigh: 895
#   utcTimestampInMinutes: 27927240
# }
# trendbar {
#   volume: 155204
#   low: 106692
#   deltaOpen: 555
#   deltaClose: 586
#   deltaHigh: 972
#   utcTimestampInMinutes: 27928680
# }
# trendbar {
#   volume: 116471
#   low: 107094
#   deltaOpen: 136
#   deltaClose: 47
#   deltaHigh: 515
#   utcTimestampInMinutes: 27930120
# }
# trendbar {
#   volume: 125671
#   low: 107070
#   deltaOpen: 34
#   deltaClose: 316
#   deltaHigh: 837
#   utcTimestampInMinutes: 27931560
# }
# trendbar {
#   volume: 131648
#   low: 106664
#   deltaOpen: 670
#   deltaClose: 106
#   deltaHigh: 864
#   utcTimestampInMinutes: 27933000
# }
# trendbar {
#   volume: 111967
#   low: 106556
#   deltaOpen: 249
#   deltaClose: 696
#   deltaHigh: 744
#   utcTimestampInMinutes: 27937320
# }
# trendbar {
#   volume: 161739
#   low: 107068
#   deltaOpen: 108
#   deltaClose: 291
#   deltaHigh: 973
#   utcTimestampInMinutes: 27938760
# }
# trendbar {
#   volume: 135582
#   low: 106606
#   deltaOpen: 764
#   deltaClose: 263
#   deltaHigh: 839
#   utcTimestampInMinutes: 27940200
# }
# trendbar {
#   volume: 142188
#   low: 106546
#   deltaOpen: 329
#   deltaClose: 182
#   deltaHigh: 680
#   utcTimestampInMinutes: 27941640
# }
# trendbar {
#   volume: 128666
#   low: 106128
#   deltaOpen: 597
#   deltaClose: 815
#   deltaHigh: 856
#   utcTimestampInMinutes: 27943080
# }
# trendbar {
#   volume: 81769
#   low: 106704
#   deltaOpen: 150
#   deltaClose: 144
#   deltaHigh: 343
#   utcTimestampInMinutes: 27947400
# }
# trendbar {
#   volume: 132376
#   low: 106376
#   deltaOpen: 479
#   deltaClose: 85
#   deltaHigh: 607
#   utcTimestampInMinutes: 27948840
# }
# trendbar {
#   volume: 140908
#   low: 105992
#   deltaOpen: 442
#   deltaClose: 57
#   deltaHigh: 650
#   utcTimestampInMinutes: 27950280
# }
# trendbar {
#   volume: 128836
#   low: 105772
#   deltaOpen: 270
#   deltaClose: 171
#   deltaHigh: 506
#   utcTimestampInMinutes: 27951720
# }
# trendbar {
#   volume: 142994
#   low: 105362
#   deltaOpen: 563
#   deltaClose: 93
#   deltaHigh: 781
#   utcTimestampInMinutes: 27953160
# }
# trendbar {
#   volume: 120589
#   low: 105329
#   deltaOpen: 110
#   deltaClose: 759
#   deltaHigh: 869
#   utcTimestampInMinutes: 27957480
# }
# trendbar {
#   volume: 123716
#   low: 105739
#   deltaOpen: 303
#   deltaClose: 16
#   deltaHigh: 714
#   utcTimestampInMinutes: 27958920
# }
# trendbar {
#   volume: 152483
#   low: 105653
#   deltaOpen: 102
#   deltaClose: 1037
#   deltaHigh: 1261
#   utcTimestampInMinutes: 27960360
# }
# trendbar {
#   volume: 140715
#   low: 105766
#   deltaOpen: 907
#   deltaClose: 205
#   deltaHigh: 960
#   utcTimestampInMinutes: 27961800
# }
# trendbar {
#   volume: 119184
#   low: 105884
#   deltaOpen: 81
#   deltaClose: 457
#   deltaHigh: 503
#   utcTimestampInMinutes: 27963240
# }
# symbolId: 1
#
#
# Trendbars received
#
# dailyBars length: 249
# \Stopping reactor...
#
# Disconnected:  [Failure instance: Traceback (failure with no frames): <class 'twisted.internet.error.ConnectionLost'>: Connection to the other side was lost in a non-clean fashion: Connection lost.
# ]

# %%
import pandas as pd

pd.DataFrame(dailyBars).rename(columns={0: "timestamp", 1: "open", 2: "high", 3: "low", 4: "close", 5: "volume"}).set_index("timestamp")
# Out:
#                               open     high      low    close  volume
# timestamp
# 2022-03-20 21:00:00+00:00  1.10574  1.10701  1.10103  1.10168  118582
# 2022-03-21 21:00:00+00:00  1.10153  1.10458  1.09610  1.10246  136869
# 2022-03-22 21:00:00+00:00  1.10238  1.10441  1.09640  1.10057  117124
# 2022-03-23 21:00:00+00:00  1.10056  1.10140  1.09660  1.09970  125945
# 2022-03-24 21:00:00+00:00  1.09941  1.10378  1.09810  1.09835  129440
# ...                            ...      ...      ...      ...     ...
# 2023-02-26 22:00:00+00:00  1.05439  1.06198  1.05329  1.06088  120589
# 2023-02-27 22:00:00+00:00  1.06042  1.06453  1.05739  1.05755  123716
# 2023-02-28 22:00:00+00:00  1.05755  1.06914  1.05653  1.06690  152483
# 2023-03-01 22:00:00+00:00  1.06673  1.06726  1.05766  1.05971  140715
# 2023-03-02 22:00:00+00:00  1.05965  1.06387  1.05884  1.06341  119184
#
# [249 rows x 5 columns]
